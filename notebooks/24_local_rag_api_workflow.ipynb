# %% [markdown]
# # 24 - Local RAG API Workflow

# %%
import httpx

payload = {'query': 'Where is context management implemented?', 'collection': 'codebase', 'top_k': 5}
response = httpx.post('http://localhost:8080/search', json=payload, timeout=30.0)
print(response.status_code)
print(response.json())
