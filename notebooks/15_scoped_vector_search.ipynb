# %% [markdown]
# # 15 - Scoped Vector Search
#
# Shows project scope retrieval with global fallback.

# %%
from agentic_assistants.vectordb.scoped_store import ScopedVectorStore

store = ScopedVectorStore(project_id='nb-15')
hits = store.search('authentication', collection='codebase', top_k=5, include_global=True, include_parent_scopes=True)
print('hits', len(hits))
