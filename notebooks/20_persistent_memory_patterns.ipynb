# %% [markdown]
# # 20 - Persistent Memory Patterns

# %%
from agentic_assistants.memory import get_memory_store

memory = get_memory_store(backend='mem0', user_id='nb-user')
memory.add_memory('Prefer concise step-by-step answers.', metadata={'type': 'preference'})
result = memory.search_memories('answer style', limit=3)
print(result.total)
