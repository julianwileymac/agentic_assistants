# %% [markdown]
# # 25 - End-to-End Local RAG Starter

# %%
from agentic_assistants.vectordb.base import Document, VectorStore
from agentic_assistants.patterns.rag_pattern import RAGPattern

store = VectorStore.create(backend='lancedb')
store.add(Document(id='e2e-1', content='End-to-end local RAG combines ingestion, retrieval, and generation.'), collection='e2e')
rag = RAGPattern(vector_store=store, collection='e2e', top_k=3)
print(rag.query('What does end-to-end local RAG include?').output)
